# %% [markdown]
# 代码的基本结构源于 `net copy.py` 和 `test.py`，为方便调试新开了notebook。

# %%
import torch
from torch import nn
from torchvision import transforms as T
from torchvision import  datasets
from torch.utils.data.dataloader import DataLoader
import torch.optim as optim
import torch.nn.functional as F
from torchinfo import summary
import os

# %%
class mixed_net(nn.Module):
    def __init__(self):
        super(mixed_net,self).__init__()
        #搭建CNN网络
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1) #[B, 32, 32, 32]
        self.bn1 = nn.BatchNorm2d(32) # [B, 32, 32, 32]

        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1) #[B, 64, 16, 16]
        self.bn2 = nn.BatchNorm2d(64) # [B, 64, 16, 16]

        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1) #[B, 128, 8, 8]
        self.bn3 = nn.BatchNorm2d(128) # [B, 128, 8, 8]

        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1) #[B, 128, 8, 8]
        self.bn4 = nn.BatchNorm2d(128) # [B, 128, 8, 8]

        # 旁支1
        self.pool = nn.MaxPool2d(2, 2) # [B, 32, 16, 16]
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1)) # [B, 32, 1, 1]

        self.dropout = nn.Dropout(0.3) # [B, 32, 1, 1]
        self.fc = nn.Linear(128, 3) # [B, 128] -> [B, 3]
    
    def forward(self, x):
        '''
        公式： W = (W + 2padding - kernel_w) / stride + 1
        这个公式是用来给手算参考的，实际这些工作已经被封装在了上面的方法中，不用自己再手动实现了。      
        '''

        x = self.pool(F.relu(self.bn1(self.conv1(x))))  # 64 -> 32
        x = self.pool(F.relu(self.bn2(self.conv2(x))))  # 32 -> 16
        x = self.pool(F.relu(self.bn3(self.conv3(x))))  # 16 -> 8

        x = F.relu(self.bn4(self.conv4(x))) # 8 -> 8

        x = self.avgpool(x) # [B, 128, 1, 1]
        x = torch.flatten(x, 1) # [B, 128]

        x = self.dropout(x) # [B, 128]
        x = self.fc(x) # [B, 128] -> [B, 3]               

        return x

# %%
if __name__ == "__main__":
    #图像转换,此处再增强一次训练集，测试集不增强
    train_transform = T.Compose([
        T.Resize([64, 64]),
        T.RandomHorizontalFlip(p=0.5),
        T.RandomRotation(10),
        T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),
        T.ToTensor(),
        T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    test_transform = T.Compose([
        T.Resize([64, 64]),
        T.ToTensor(),
        T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

    #超参数设置
    BATCH_SIZE = 1024
    EPOCH = 200 #训练轮数，实际上几百轮下来模型预测的准确率就会在一个小区间摆荡，再高已经没有意义，想真正提高准确率应该从网络结构、优化器、学习率等处下手。

    #加载数据
    trainset = datasets.ImageFolder(root=r'dataset/train',transform=train_transform)
    testset1 = datasets.ImageFolder(root=r'dataset/test1',transform=test_transform)
    testset2 = datasets.ImageFolder(root=r'dataset/test2',transform=test_transform)

    print(f"训练集图片数量: {len(trainset)}")
    print(f"测试集1图片数量: {len(testset1)}")
    print(f"测试集2图片数量: {len(testset2)}")
    
    train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
    test_loader1 = DataLoader(testset1, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
    test_loader2 = DataLoader(testset2, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

    #创建网络
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu") #这里一开始使用的工作环境似乎是MAC，把mps修改为cuda就能正常在windows和linux上跑了
    net = mixed_net().to(device)
    
    #打印网络信息
    summary(net, input_size=(1, 3, 64, 64), device=device)
    print(f'标签对应的ID: {trainset.class_to_idx}')

    #设置优化器、损失函数
    criterion = nn.CrossEntropyLoss()
    optimizer =optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
    # optimizer = optim.Adam(net.parameters(), lr=0.001, weight_decay=1e-4)

    #开始训练

    print("Start")
    for epoch in range(EPOCH):
        train_loss = 0.0
        #print(epoch)
        
        for batch_id, (datas, labels) in enumerate(train_loader):
            datas, labels = datas.to(device), labels.to(device)

            optimizer.zero_grad()

            outputs = net(datas)

            loss = criterion(outputs, labels)

            loss.backward()

            optimizer.step()

            train_loss += loss.item()

            if epoch > 50 and (epoch + 1) % 10 == 0:
                os.makedirs("pth", exist_ok=True)
                PATH = "pth/modeltemp.pth"
                torch.save(net.state_dict(), PATH)
                model = mixed_net()
                model.load_state_dict(torch.load(PATH))
                model.eval()
                model.to(device)

                #限定保存条件
                #只有满足以下条件时才会真正保存模型文件
                #没有打印保存信息代表模型不理想，此时启动后续的测试部分会直接报错找不到模型！
                max_correct = 99
                correct1 = 0
                correct2 = 0
                total1 = 0
                total2 = 0

                #分别测试两个数据集
                with torch.no_grad():
                    for i ,(datas1, labels1) in enumerate(test_loader1):
                        datas1, labels1 = datas1.to(device), labels1.to(device)
                        output_test1 = model(datas1)
                        _, predicted1 = torch.max(output_test1.data, dim=1)
                        total1 += predicted1.size(0)
                        correct1 += (predicted1 == labels1).sum()

                    for i ,(datas2, labels2) in enumerate(test_loader2):
                        datas2, labels2 = datas2.to(device), labels2.to(device)
                        output_test2 = model(datas2)
                        _, predicted2 = torch.max(output_test2.data, dim=1)
                        total2 += predicted2.size(0)
                        correct2 += (predicted2 == labels2).sum()

                    #打印消息
                    c1 = 0
                    c2 = 0
                    c2 = correct2 / total2 * 100
                    c1 = correct1 / total1 * 100
                    print(
                        f"epoch:{epoch + 1}\tbatch_id:{batch_id + 1}\taverage_loss:{(train_loss / len(train_loader.dataset)):.5f}\t"
                        f"correct1:{c1:.2f}%\tcorrect2:{c2:.2f}%"
                    )
                    if (c1 > max_correct):
                        max_correct = c1
                        MAX_PATH = f"pth/model_best_{max_correct}.pth"
                        print(f"save {MAX_PATH}")
                        torch.save(net.state_dict(),MAX_PATH)
# Out:
# 训练集图片数量: 1298
# 测试集1图片数量: 217
# 测试集2图片数量: 140
# 标签对应的ID: {'blue': 0, 'red': 1, 'yellow': 2}
# Start
# epoch:60	batch_id:1	average_loss:0.00006	correct1:97.24%	correct2:95.71%
# epoch:60	batch_id:2	average_loss:0.00013	correct1:98.16%	correct2:94.29%
# epoch:70	batch_id:1	average_loss:0.00004	correct1:99.08%	correct2:95.71%
# save pth/model_best_99.07833862304688.pth
# epoch:70	batch_id:2	average_loss:0.00010	correct1:98.62%	correct2:95.71%
# epoch:80	batch_id:1	average_loss:0.00004	correct1:99.54%	correct2:97.14%
# save pth/model_best_99.53916931152344.pth
# epoch:80	batch_id:2	average_loss:0.00007	correct1:99.54%	correct2:96.43%
# save pth/model_best_99.53916931152344.pth
# epoch:90	batch_id:1	average_loss:0.00003	correct1:99.54%	correct2:96.43%
# save pth/model_best_99.53916931152344.pth
# epoch:90	batch_id:2	average_loss:0.00007	correct1:100.00%	correct2:96.43%
# save pth/model_best_100.0.pth
# epoch:100	batch_id:1	average_loss:0.00002	correct1:100.00%	correct2:95.71%
# ...

# %%
def test_model(model_path, test_loader):
    #加载模型
    model = mixed_net()
    model.load_state_dict(torch.load(model_path))
    model.eval()  

    #初始化计数器
    class_correct = list(0. for i in range(3))
    class_total = list(0. for i in range(3))

    #开始测试
    with torch.no_grad():
        for i ,(datas, labels) in enumerate(test_loader):
            output_test = model(datas)
            _, predicted1 = torch.max(output_test.data, dim=1)

            matches = (predicted1 == labels)
            for i in range(len(labels)):
                label = labels[i]
                class_correct[label] += matches[i].item()
                class_total[label] += 1

    #计算总体正确率
    total_correct = sum(class_correct)
    total = sum(class_total)
    accuracy = 100.0 * total_correct / total
    print(f'Overall Accuracy: {accuracy:.2f}%')

    #输出每个类别的正确率
    for i in range(3):
        print(f'Accuracy of Class {i}: {100 * class_correct[i] / class_total[i]:.2f}%')

# %%
#图像转换
test_transforms = T.Compose([
    T.Resize([64, 64]),
    T.ToTensor(),
    T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

#加载数据
BATCH_SIZE = 1024
testset1 = datasets.ImageFolder(root=r'dataset/test1',transform=test_transforms)
testset2 = datasets.ImageFolder(root=r'dataset/test2',transform=test_transforms)
test_loader1 = DataLoader(testset1, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)
test_loader2 = DataLoader(testset2, batch_size=BATCH_SIZE, shuffle=True, pin_memory=True)

#调用测试函数
model_path = r"pth/model_best_100.0.pth" 
test_model(model_path, test_loader1)
test_model(model_path, test_loader2)
# Out:
# Overall Accuracy: 100.00%
# Accuracy of Class 0: 100.00%
# Accuracy of Class 1: 100.00%
# Accuracy of Class 2: 100.00%
# Overall Accuracy: 95.00%
# Accuracy of Class 0: 98.00%
# Accuracy of Class 1: 87.76%
# Accuracy of Class 2: 100.00%
